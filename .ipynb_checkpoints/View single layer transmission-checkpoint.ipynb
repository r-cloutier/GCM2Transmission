# %%
from GCM2ExoTransmit import *
import matplotlib.gridspec as gridspec
# %matplotlib inline

# %%
# get spectra from layers and GCM data
simname = 'earth'
layerdirs = np.sort(np.array(glob.glob('../Exo_Transmit/Spectra/GCM/terminator/%s_layer*'%simname)))
time,lon,lat,h,Ps,P,T,X_H2O,clouds = get_GCM_data('plasim_samples/%s.nc'%simname)
Ntime, Nh, Nlat, Nlon = T.shape
assert layerdirs.size == Nh
tindex = 11
cloudP = 5e3

# %%
# get averge termintor water vapour in each layer
X_H2Oavg = np.zeros(Nh)
for h in range(Nh):
    X_H2Otmp = np.zeros(0)
    for i in range(Nlat):
        for j in range(Nlon):
            if at_terminator(lat[i], lon[j]):
                X_H2Otmp = np.append(X_H2Otmp, X_H2O[tindex,h,i,j])
    X_H2Oavg[h] = X_H2Otmp.mean()

# %%
# plot transmission in layers and water content
plt.figure(figsize=(6,13))
gs = gridspec.GridSpec(Nh,5)

# plot water
axX = plt.subplot(gs[:,-2:])
axX.plot(X_H2Oavg, P*1e-5, 'k-'), axX.set_ylim((P.max()*1e-5,P.min()*1e-5))
axX.axhline(cloudP*1e-5, ls='--', c='b'), axX.text(5e-5, cloudP*1e-5+4e-3, 'cloud deck', color='b')
axX.set_xscale('log'), axX.set_xlabel('Water Mixing Ratio'), axX.set_ylabel('Pressure [bar]')

# plot transmission spectra
for i in range(Nh):
    print '%s/earth_layer%i.dat'%(layerdirs[i],i)
    wl, spec = np.loadtxt('%s/earth_layer%i.dat'%(layerdirs[i],i)).T
    wl *= 1e6
    ax = plt.subplot(gs[i,:-2])
    ax.plot(wl, spec, 'k-', lw=.9)
    ax.set_xscale('log'), ax.set_xlim((.5,30)), ax.set_ylim((.21,.215))
# Out:
# ../Exo_Transmit/Spectra/GCM/terminator/earth_layer0/earth_layer0.dat
# ../Exo_Transmit/Spectra/GCM/terminator/earth_layer1/earth_layer1.dat
# ../Exo_Transmit/Spectra/GCM/terminator/earth_layer2/earth_layer2.dat
# ../Exo_Transmit/Spectra/GCM/terminator/earth_layer3/earth_layer3.dat
# ../Exo_Transmit/Spectra/GCM/terminator/earth_layer4/earth_layer4.dat
# ../Exo_Transmit/Spectra/GCM/terminator/earth_layer5/earth_layer5.dat
# ../Exo_Transmit/Spectra/GCM/terminator/earth_layer6/earth_layer6.dat
# ../Exo_Transmit/Spectra/GCM/terminator/earth_layer7/earth_layer7.dat
# ../Exo_Transmit/Spectra/GCM/terminator/earth_layer8/earth_layer8.dat
# ../Exo_Transmit/Spectra/GCM/terminator/earth_layer9/earth_layer9.dat
